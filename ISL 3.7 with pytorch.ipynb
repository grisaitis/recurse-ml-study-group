# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

import torch
import torch.nn as nn

# %matplotlib inline
plt.style.use('seaborn-white')

# %% [markdown]
# ## Load data

# %%
auto = pd.read_csv('http://faculty.marshall.usc.edu/gareth-james/ISL/Auto.csv', na_values='?').dropna()

# %%
auto.sample(10, replace=False)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0       130.0    3504          12.0    70
# 272  23.8          4         151.0        85.0    2855          17.6    78
# 191  22.0          6         225.0       100.0    3233          15.4    76
# 17   21.0          6         200.0        85.0    2587          16.0    70
# 123  20.0          6         156.0       122.0    2807          13.5    73
# 348  37.7          4          89.0        62.0    2050          17.3    81
# 151  31.0          4          79.0        67.0    2000          16.0    74
# 40   14.0          8         351.0       153.0    4154          13.5    71
# 294  34.1          4          86.0        65.0    1975          15.2    79
# 72   15.0          8         304.0       150.0    3892          12.5    72
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# 272       1     oldsmobile starfire sx
# ...

# %% [markdown]
# are there any null / NaN rows?

# %%
len(auto)
# Out:
# 392

# %%
auto[auto.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, year, origin, name]
# Index: []

# %% [markdown]
# ## Data viz

# %%
sns.pairplot(
    auto,
    vars=["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "year"],
    hue="origin"
)

# %% [markdown]
# ## PyTorch matrix operations

# %%
x = torch.Tensor([[1, 2, 3], [4, 5, 6]])
y = torch.Tensor([[1, 2], [3, 4], [5, 6]])

# %%
[x.size(), y.size()]
# Out:
# [torch.Size([2, 3]), torch.Size([3, 2])]

# %%
x @ y
# Out:
# tensor([[22., 28.],
#         [49., 64.]])

# %%
torch.mm(x, y)
# Out:
# tensor([[22., 28.],
#         [49., 64.]])

# %% [markdown]
# ## Modeling

# %%
# the validation set approach

# split data into train and test

# fit model to train

# evaluate on test

# store result

# plot test errors of various levels of

# %%
import numpy as np

# %%
rs = np.random.RandomState(seed=0)

# %%
rs.uniform(size=(10,))
# Out:
# array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#        0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152])

# %%
np.random.RandomState(seed=0).uniform(size=(10,))
# Out:
# array([0.5488135 , 0.71518937, 0.60276338, 0.54488318, 0.4236548 ,
#        0.64589411, 0.43758721, 0.891773  , 0.96366276, 0.38344152])

# %%
rs.normal(size=((10,1)))
# Out:
# array([[ 0.14404357],
#        [ 1.45427351],
#        [ 0.76103773],
#        [ 0.12167502],
#        [ 0.44386323],
#        [ 0.33367433],
#        [ 1.49407907],
#        [-0.20515826],
#        [ 0.3130677 ],
#        [-0.85409574]])

# %%
for (i_train, i_test) in train_test_splits:
    for l2_penalty in np.arange(0, 1, 0.1):

# %%
cv_results = pd.DataFrame(dict(
    train_set_id=range(10),
    l2_penalty=np.arange(0, 1, 0.1),
    mse=rs.random(size=((10,1))),
))
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-16-90902ca1e33f> in <module>
#       2     train_set_id=range(10),
#       3     l2_penalty=np.arange(0, 1, 0.1),
# ----> 4     mse=rs.random(size=((10,1))),
#       5 ))
#
# ~/.local/share/virtualenvs/ml-study-group-ExtSe04q/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~/.local/share/virtualenvs/ml-study-group-ExtSe04q/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
# ...

# %% [markdown]
# ### Plot cross validated results

# %%
cv_results.plot()

# %% [markdown]
# ## Sandbox... pytorch models

# %%
# the leave one out approach

# %%
# k fold approach

# %%
class LinearRegression(nn.Module):
    def __init__(self):
        super(self.__class__, self).__init__()
        self.linear = nn.Linear(1, 1)  # input and output is 1 dimension

    def forward(self, x):
        return self.linear(x)

# %%
model = LinearRegression()

# %%
criterios = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=1e-4)

num_epochs = 1000
for epoch in range(num_epochs):
    inputs = x_train
    target = y_train

    # forward
    out = model(inputs)
    loss = criterion(out, target)
    # backward
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (epoch+1) % 20 == 0:
        print(f'Epoch[{epoch+1}/{num_epochs}], loss: {loss.item():.6f}')

# %%
fitter = SGDFitter(
    criterion=nn.MSELoss()
)

# %%
fitter.fit()

# %% [markdown]
# ## PyTorch array buffers (numpy <-> tensor)

# %%
a = np.array([1, 2, 3])
b = torch.from_numpy(a)         # Convert a numpy array to a Tensor

# %%
a

# %%
b

# %%
b[2] = 5

# %%
b

# %%
a

# %%
c = b.numpy()

# %%
c[1] = -1

# %%
a

# %%
b

# %%
c
